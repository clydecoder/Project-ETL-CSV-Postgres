# %% [markdown]
# <a href="https://colab.research.google.com/github/clyderodrigo/Project-ETL-CSV-Postgres/blob/main/Project_ETL_CSV_Postgres.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# !ls
# Out:
# /content
# drive  sample_data

# %%
# %cd drive/MyDrive/1-Data-Science/1-Data-Engineering-Projects
# Out:
# /content/drive/MyDrive/1-Data-Science/1-Data-Engineering-Projects

# %%
import psycopg2
import pandas as pd

# %%
def create_database():
    # connect to default database
    conn = psycopg2.connect(host="rosie.db.elephantsql.com", database="koxdgtnq", user="koxdgtnq", password="hyik6zNrT28enwS3KAMIhRtCMlG4J2Ez")
    conn.set_session(autocommit=True)
    cur = conn.cursor()
    
    # create accounts database
    #cur.execute("DROP DATABASE IF EXISTS accounts")
    #cur.execute("CREATE DATABASE accounts")

    # close connection to default database
    #conn.close()    
    
    # connect to accounts database
    #conn = psycopg2.connect(host="rosie.db.elephantsql.com", database="accounts", user="koxdgtnq", password="hyik6zNrT28enwS3KAMIhRtCMlG4J2Ez")
    #cur = conn.cursor()
    
    return cur, conn

# %%
def drop_tables(cur, conn):
  for query in drop_table_queries:
    cur.execute(query)
    conn.commit()

# %%
def create_tables(cur, conn):
  for query in create_table_queries:
    cur.execute(query)
    conn.commit()

# %%
AccountsCountry = pd.read_csv("Wealth-Data/Wealth-AccountsCountry.csv")

# %%
AccountsCountry.head()
# Out:
#   Code                  Long Name         Income Group  \
# 0  ALB        Republic of Albania  Upper middle income
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# 1                                    2020 (expected)
# ...

# %%
AccountsCountry_clean = AccountsCountry[['Code','Long Name','Region','Income Group','Currency Unit']]

# %%
AccountsCountry_clean.head()
# Out:
#   Code                  Long Name                     Region  \
# 0  ALB        Republic of Albania      Europe & Central Asia
# 1  ARG         Argentine Republic  Latin America & Caribbean
# 2  ARM        Republic of Armenia      Europe & Central Asia
# 3  AUS  Commonwealth of Australia        East Asia & Pacific
# 4  AUT        Republic of Austria      Europe & Central Asia
#
#           Income Group      Currency Unit
# 0  Upper middle income       Albanian lek
# 1  Upper middle income     Argentine peso
# 2  Upper middle income      Armenian dram
# 3          High income  Australian dollar
# 4          High income               Euro

# %%
AccountsData = pd.read_csv("Wealth-Data/Wealth-AccountData.csv")

# %%
AccountsData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
AccountsData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
AccountsData = AccountsData.drop(['1995 [YR1995]'], axis=1)

# %%
AccountsData = AccountsData[['Country Name', 'Country Code', 'Series Name', 'Series Code', '1996 [YR1996]', '2005 [YR2005]', '2010 [YR2010]', '2015 [YR2015]']]

# %%
AccountsData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1996 [YR1996]  2005 [YR2005]  2010 [YR2010]  2015 [YR2015]
# 0      4.34E+10   5.440000e+10   6.810000e+10   7.370000e+10
# 1      13708.99   1.807230e+04   2.336286e+04   2.559371e+04
# 2      3355.549   2.222115e+03   2.889150e+03   2.987545e+03
# 3      6353.737   1.168935e+04   1.578992e+04   1.730701e+04
# 4      4737.857   2.886736e+03   3.613606e+03   3.767628e+03

# %%
AccountsSeries = pd.read_csv("Wealth-Data/Wealth-AccountSeries.csv")

# %%
AccountsSeries.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
AccountsSeries.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name'],
#       dtype='object')

# %%
AccountsSeries = AccountsSeries[['Code','Topic','Indicator Name','Reference period']]

# %%
AccountsSeries.head()
# Out:
#              Code          Topic  \
# 0       NW.HCA.TO  Human capital
# 1       NW.HCA.PC  Human capital
# 2  NW.HCA.FEMP.PC  Human capital
# 3  NW.HCA.MEMP.PC  Human capital
# 4  NW.HCA.FEMA.PC  Human capital
#
#                                       Indicator Name Reference period
# 0                  Human capital (constant 2018 US$)        1995-2018
# 1       Human capital per capita (constant 2018 US$)        1995-2018
# 2  Human capital per capita, employed female (con...        1995-2018
# 3  Human capital per capita, employed male (const...        1995-2018
# 4  Human capital per capita, female (constant 201...        1995-2018

# %%
cur, conn = create_database()

# %%
accountscountry_table_create = ("""CREATE TABLE IF NOT EXISTS accountscountry(
country_code VARCHAR PRIMARY KEY,
long_name VARCHAR,
region VARCHAR,
income_group VARCHAR,
currency_unit VARCHAR
)""")

# %%
cur.execute(accountscountry_table_create)
conn.commit()

# %%
accountsdata_table_create = ("""CREATE TABLE IF NOT EXISTS accountsdata(
country_name VARCHAR,
country_code VARCHAR,
series_name VARCHAR,
series_code VARCHAR,
year_1996 numeric,
year_2005 numeric,
year_2010 numeric,
year_2015 numeric
)""")
cur.execute(accountsdata_table_create)
conn.commit()

# %%
accountsseries_table_create = ("""CREATE TABLE IF NOT EXISTS accountsseries(
series_code VARCHAR,
topic VARCHAR,
indicator_name VARCHAR,
reference_period VARCHAR
)""")
cur.execute(accountsseries_table_create)
conn.commit()

# %%
accountscountry_table_insert = ("""INSERT INTO accountscountry(
country_code,
long_name,
region,
income_group,
currency_unit)
VALUES (%s, %s, %s, %s, %s)
ON CONFLICT (country_code) DO NOTHING""")

# %%
AccountsCountry_clean
# Out:
#      Code                            Long Name                     Region  \
# 0     ALB                  Republic of Albania      Europe & Central Asia
# 1     ARG                   Argentine Republic  Latin America & Caribbean
# 2     ARM                  Republic of Armenia      Europe & Central Asia
# 3     AUS            Commonwealth of Australia        East Asia & Pacific
# 4     AUT                  Republic of Austria      Europe & Central Asia
# ...   ...                                  ...                        ...
# 7592  NaN                                  NaN                        NaN
# 7593  NaN                                  NaN                        NaN
# 7594  NaN                                  NaN                        NaN
# 7595  NaN  Data from database: Wealth Accounts                        NaN
# 7596  NaN             Last Updated: 10/27/2021                        NaN
#
#                              Income Group      Currency Unit
# ...

# %%
for i, row in AccountsCountry_clean.iloc[:1000].iterrows():
  #print(row)
  #print(list(row))
  cur.execute(accountscountry_table_insert, list(row))

# %%
conn.commit()

# %%
accountsdata_table_insert = ("""INSERT INTO accountsdata(
country_name,
country_code,
series_name,
series_code,
year_1996,
year_2005,
year_2010,
year_2015)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
""")

# %%
for i, row in AccountsData.iloc[:1000].iterrows():
  #print(list(row))
  cur.execute(accountsdata_table_insert, list(row))

# %%
conn.commit()

# %%
accountsseries_table_insert = ("""INSERT INTO accountsseries(
series_code,
topic,
indicator_name,
reference_period)
VALUES(%s, %s, %s, %s)
""")

# %%
for i, row in AccountsSeries.iterrows():
  #print(row)
  #print(list(row))
  cur.execute(accountsseries_table_insert, list(row))

# %%
conn.commit()
